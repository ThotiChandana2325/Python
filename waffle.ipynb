# %%
pip install pywaffle
# Out:
# ...
#   Using cached pywaffle-1.1.0-py2.py3-none-any.whl (30 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/25.3 MB 16.8 kB/s eta 0:24:59
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/chandana/anaconda3/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 437, in _error_catcher
#     yield
#   File "/home/chandana/anaconda3/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 560, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/chandana/anaconda3/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 526, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/home/chandana/anaconda3/lib/python3.10/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "/home/chandana/anaconda3/lib/python3.10/http/client.py", line 465, in read
#     s = self.fp.read(amt)
# ...

# %%
pip install pywaffle
# Out:
# ...
#   Using cached pywaffle-1.1.0-py2.py3-none-any.whl (30 kB)
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/5d/84/a3b769041cc5f9c9ee048e16c7750fb195cf29f43d73d98eb2c55c17ddb1/fontawesomefree-6.4.2-py3-none-any.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/25.3 MB 14.0 kB/s eta 0:29:47
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/chandana/anaconda3/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 437, in _error_catcher
#     yield
#   File "/home/chandana/anaconda3/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 560, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/chandana/anaconda3/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 526, in _fp_read
# ...

# %%
from wordcloud import STOPWORDS,WordCloud
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from wordcloud import STOPWORDS,WordCloud
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
pip install wordcloud
# Out:
# ERROR: Could not find a version that satisfies the requirement wordcloud (from versions: none)
# ERROR: No matching distribution found for wordcloud
# Note: you may need to restart the kernel to use updated packages.

# %%
file=open("text.txt","w")
file.write("this is text file")
# Out:
# 17

# %%
f=
f.write("new text file")
# Out:
# 13

# %%
with open("file.txt","w") as f:
    f.write("hello....World")

# %%
with open("file.txt", "a") as f:
    f.write("bye bye")

# Display the content in the Jupyter Notebook cell
#with open("file.txt", "r") as f:
   # content = f.read()
   # print(content)

# %%
from pywaffle import Waffle
import matplotlib.pyplot as plt
#data={"veh":["car","bus","bike"],"num":[24,56,15]}
#data=pd.DataFrame()
veh=["car","bus","truck","train","plane"]
fig=plt.figure(FigureClass=Waffle,rows=8,values=[10,25,15,24,35],colors=['red','blue','green','grey','black'],icons=veh)
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
from wordcloud import STOPWORDS,WordCloud
import matplotlib.pyplot as plt
import pandas as pd
import numpy as  np
from PIL import Image
text=open("file.txt","r").read()
w=WordCloud(background_color="white",mask=np.array(Image.open("/home/chandana/Pictures/budda.jpeg")))
w.generate(text)
plt.imshow(w)
plt.axis("off")
plt.show()

# %%
text=open("file.txt","r").read()
w=WordCloud()
w.generate(text)
plt.imshow(w)
plt.axis("off")
plt.show()
